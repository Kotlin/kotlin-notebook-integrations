// %%
USE {
    repositories { mavenLocal() }
    dependencies {
        implementation("org.jetbrains.kotlinx:kotlin-jupyter-widgets-jupyter:0.3.0-1-SNAPSHOT")
    }
}
// TODO should use %use widgets

// %% [markdown]
// ### Int slider

// %%
widgetManager.intSlider().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntSliderModel(id=b68f288a-c25c-4558-be27-d5ee2d604733)

// %% [markdown]
// ### Float sliders

// %%
widgetManager.floatSlider().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=f22fa4be-c2b4-4661-8c5d-9ab3dad4343e)

// %%
widgetManager.floatSlider().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Vertical
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=52205a59-bdee-43d2-9cc1-d6010e2de902)

// %%
widgetManager.floatLogSlider().apply {
    value = 10.0
    base = 10.0
    min = -10.0
    max = 10.0
    step = 0.2
    description = "Log Slider"
}
// Out:
// FloatLogSliderModel(id=c58c329f-2032-4354-b9d6-774f836e5835)

// %% [markdown]
// ### Range sliders and progress

// %%
widgetManager.intRangeSlider().apply {
    value = listOf(5, 7) // TODO should better be an `IntRange`
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntRangeSliderModel(id=6085760a-d3b7-48d4-a2fa-1d33c426249b)

// %%
widgetManager.floatRangeSlider().apply {
    value = listOf(5.0, 7.5) // TODO should better be a `DoubleRange`
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatRangeSliderModel(id=985f98ba-a675-436a-b8e7-647d45b1f22e)

// %%
widgetManager.intProgress().apply {
    value = 7
    min = 0
    max = 10
    description = "Loading:"
    barStyle = BarStyle.Default
    style = progressStyleWidget().apply { barColor = "maroon" }
    orientation = Orientation.Horizontal
}
// Out:
// IntProgressModel(id=20da403d-3a9e-460f-accf-c88d436d2f45)

// %%
widgetManager.floatProgress().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    description = "Loading:"
    barStyle = BarStyle.Info
    style = progressStyleWidget().apply { barColor = "#ffff00" }
    orientation = Orientation.Horizontal
}
// Out:
// FloatProgressModel(id=85f26fde-2431-42d5-917c-bab6dd288d39)

// %% [markdown]
// ### Numeric text widgets

// %%
widgetManager.boundedIntText().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedIntTextModel(id=27460771-f9fa-456b-a363-7da3ef09d836)

// %%
widgetManager.boundedFloatText().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedFloatTextModel(id=b6f52d8a-6968-412a-a851-5c10fa8c5755)

// %%
widgetManager.intText().apply {
    value = 7
    description = "Any:"
    disabled = false
}
// Out:
// IntTextModel(id=ae402f18-3792-4d73-9fdf-f60c3b9db3f6)

// %%
widgetManager.floatText().apply {
    value = 7.5
    description = "Any:"
    disabled = false
}
// Out:
// FloatTextModel(id=4ed9588d-c6f5-4a4f-a6d7-ae6700f52f39)

// %% [markdown]
// ### Toggles and indicators

// %%
widgetManager.toggleButton().apply {
    value = false
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Description"
    icon = "check"
}
// Out:
// ToggleButtonModel(id=ac9e0c8b-3600-4191-908d-be0caa17de15)

// %%
widgetManager.checkbox().apply {
    value = false
    description = "Check me"
    disabled = false
    indent = false
}
// Out:
// CheckboxModel(id=7d8c664d-0190-4cef-8806-6eec8f6ecd3e)

// %%
widgetManager.valid().apply {
    value = false
    description = "Valid!"
}
// Out:
// ValidModel(id=e216ec81-bc5a-46a2-8c3b-9aa9e7e6b7a2)

// %% [markdown]
// ### Dropdowns and radios

// %%
// TODO `value`, `label`, and `options` are missing
widgetManager.dropdown().apply {
    // TODO should be readOnly
    optionsLabels = listOf("1", "2", "3")
    index = 1
    description = "Number:"
    disabled = false
}
// Out:
// DropdownModel(id=8f2cc988-180b-4e4a-b326-4c278c95a1a5)

// %%
// TODO `value`, `label`, and `options` are missing
widgetManager.dropdown().apply {
    // TODO impossible to do
    //  options = listOf(
    //      "One" to 1,
    //      "Two" to 2,
    //      "Three" to 3
    //  )
    //  value = 2
    description = "Number:"
}
// Out:
// DropdownModel(id=601a573d-87ae-4403-ab0e-e8032603ddd2)

// %%
widgetManager.radioButtons().apply {
    // TODO options = listOf("pepperoni", "pineapple", "anchovies")
    optionsLabels = listOf("pepperoni", "pineapple", "anchovies")
    // TODO value = "pineapple" // defaults to "pineapple"
    // layout = layoutWidget().apply { width = "max-content" } // If the items' names are long
    description = "Pizza topping:"
    disabled = false
}
// Out:
// RadioButtonsModel(id=204183be-ac19-4bd2-a351-5637177d5cbe)

// %%
widgetManager.box().apply {
    children = listOf(
        labelWidget().apply { value = "Pizza topping with a very long label:" },
        radioButtonsWidget().apply {
            // TODO options = ...
            optionsLabels = listOf(
                "pepperoni",
                "pineapple",
                "anchovies",
                "and the long name that will fit fine and the long name that will fit fine and the long name that will fit fine "
            )
            layout = layoutWidget().apply { width = "max-content" }
        },
    )
}
// Out:
// BoxModel(id=48bc9267-8971-4629-b0e7-5946d00ab7ac)

// %% [markdown]
// ### Selection widgets

// %%
widgetManager.select().apply {
    // TODO options = listOf("Linux", "Windows", "OSX")
    // TODO value = "OSX"
    optionsLabels = listOf("Linux", "Windows", "OSX")
    index = 2
    // rows = 10
    description = "OS:"
    disabled = false
}
// Out:
// SelectModel(id=435a815d-ba72-46d3-b6c1-119996da5537)

// %%
widgetManager.selectionSlider().apply {
    // TODO options = listOf("scrambled", "sunny side up", "poached", "over easy")
    // TODO value = "sunny side up"
    optionsLabels = listOf("scrambled", "sunny side up", "poached", "over easy")
    index = 1
    description = "I like my eggs ..."
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
}
// Out:
// SelectionSliderModel(id=617f3fb6-7190-4509-a9b4-0bc6923b0a8e)

// %%
%use datetime

// %%
val dates = (1..12).map { LocalDate(2015, it, 1) }
val options = dates.map { it.month.name.lowercase().replaceFirstChar(Char::titlecase) to it }
widgetManager.selectionRangeSlider().apply {
    // TODO this.options = options // currently impossible to have a different value/label
    optionsLabels = options.map { it.first }
    index = listOf(0, 11) // TODO should be IntRange
    description = "Months (2015)"
    disabled = false
}
// Out:
// SelectionRangeSliderModel(id=84608ff2-0bb7-4a4d-8f9a-215338976d1b)

// %%
widgetManager.toggleButtons().apply {
    // TODO options = listOf("Slow", "Regular", "Fast")
    optionsLabels = listOf("Slow", "Regular", "Fast")
    description = "Speed:"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltips = listOf("Description of slow", "Description of regular", "Description of fast")
    icons = List(3) { "check" }
}
// Out:
// ToggleButtonsModel(id=5675e5dc-de89-45ec-acca-41b674b9b590)

// %%
widgetManager.selectMultiple().apply {
    // TODO options = listOf("Apples", "Oranges", "Pears")
    optionsLabels = listOf("Apples", "Oranges", "Pears")
    // TODO value = listOf("Oranges")
    index = listOf(1)
    // rows = 10
    description = "Fruits"
    disabled = false
}
// Out:
// SelectMultipleModel(id=ff352711-95e9-4c1d-9526-f7a8e5c84de3)

// %% [markdown]
// ### Text inputs

// %%
widgetManager.text().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextModel(id=9a3f7e96-4684-440a-b54e-46e0326ba6a6)

// %%
widgetManager.textarea().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextareaModel(id=9a9c4830-eb64-4abb-abf4-da0b0869e072)

// %%
widgetManager.combobox().apply {
    // value = "John"
    options = listOf("Paul", "John", "George", "Ringo")
    placeholder = "Choose Someone"
    description = "Combobox:"
    ensureOption = true
    disabled = false
}
// Out:
// ComboboxModel(id=40a35d9b-0924-4c80-ae5f-fc536fd422b2)

// %%
widgetManager.password().apply {
    value = "password"
    placeholder = "Enter password"
    description = "Password:"
    disabled = false
}
// Out:
// PasswordModel(id=97d792b8-cee9-4381-b16b-d39d00d60920)

// %% [markdown]
// ### Layout helpers and HTML

// %%
widgetManager.hbox().apply {
    children = listOf(
        labelWidget().apply { value = "The label" },
        floatSliderWidget()
    )
}
// Out:
// HBoxModel(id=3363643c-c50a-4c1f-8657-7012282adfb0)

// %%
widgetManager.html().apply {
    value = "Hello <b>World</b>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLModel(id=4ecc32b1-ac23-41ae-ae15-5ce0858a9216)

// %%
widgetManager.htmlMath().apply {
    value = "Some<i>HTML</i>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLMathModel(id=ea6a176d-81e0-4db9-b0fe-45a39d611eed)

// %%
import java.io.File

val image = File("WidgetArch.png").readBytes()
widgetManager.image().apply {
    value = image
    format = "png"
    width = "300" // TODO should probably be Int
    height = "400"
}
// Out:
// ImageModel(id=5e2a9fb8-ae96-43e4-9c60-e8f156b8d124)

// %% [markdown]
// ### Buttons and links

// %%
val button = widgetManager.button().apply {
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Click me"
    icon = "check" // FontAwesome names without the `fa-` prefix)
}
button
// Out:
// ButtonModel(id=0b3d19ce-fddb-4df7-9916-bc96ac94b553)

// %%
val play = widgetManager.play().apply {
    value = 50
    min = 0
    max = 100
    step = 1
    interval = 500
    description = "Press play"
    disabled = false
}
val slider = widgetManager.intSlider()
// TODO jslink(play to "value", slider to "value")
// TODO missing TupleType or PairType
//   widgetManager.link().apply {
//       source = listOf(play, "value") // TODO should definitely be a Pair<Widget, String>
//       target = listOf(slider, "value")
//   }
widgetManager.hbox().apply { children = listOf(play, slider) }
// Out:
// HBoxModel(id=cbfd8936-63fb-47cb-9123-712b822a83d3)

// %% [markdown]
// ### Pickers and upload

// %%
widgetManager.datePicker().apply {
    description = "Pick a Date"
    disabled = false
}
// Out:
// DatePickerModel(id=67187f9a-2134-4e76-b3f0-19aa073678b3)

// %%
widgetManager.colorPicker().apply {
    concise = false
    description = "Pick a color"
    value = "blue"
    disabled = false
}
// Out:
// ColorPickerModel(id=927c6f77-4f9f-4163-99ba-399f3b7e709c)

// %%
widgetManager.fileUpload().apply {
    accept = "" // Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple = false // true to accept multiple files upload else false
}
// Out:
// FileUploadModel(id=9f871740-b089-48d7-aa87-1014570b4974)

// %%
widgetManager.controller().apply { index = 0 }
// Out:
// ControllerModel(id=75745186-9d18-481b-a584-280dc6a766b3)

// %% [markdown]
// ### Containers

// %%
val itemsBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.box().apply {
    children = itemsBox
}
// Out:
// BoxModel(id=0ae1508d-e8a5-44b2-869f-e02f6178878d)

// %%
val itemsHBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.hbox().apply {
    children = itemsHBox
}
// Out:
// HBoxModel(id=c5197d9a-d7d5-42a7-866d-2e82a4c06bf2)

// %%
val items = List(4) { widgetManager.label().apply { value = it.toString()} }
val leftBox = widgetManager.vbox().apply { children = listOf(items[0], items[1]) }
val rightBox = widgetManager.vbox().apply { children = listOf(items[2], items[3]) }
widgetManager.hbox().apply { children = listOf(leftBox, rightBox) }
// Out:
// HBoxModel(id=3939d9af-7314-4688-a6b0-885a5a283c80)

// %%
val gridItems = List(8) { widgetManager.label().apply { value = it.toString() } }
widgetManager.gridBox().apply {
    children = gridItems
    layout = layoutWidget().apply { gridTemplateColumns = "repeat(3, 100px)" }
}
// Out:
// GridBoxModel(id=76ae94c2-33d3-45e6-afcd-274582dd263f)

// %%
val accordion = widgetManager.accordion().apply {
    children = listOf(widgetManager.intSlider(), widgetManager.text())
    titles = listOf("Slider", "Text")
}
accordion
// Out:
// AccordionModel(id=b706fbae-1bee-4e40-bac2-4ba5f6dedb25)

// %%
val tabContents = listOf("P0", "P1", "P2", "P3", "P4")
val _children = tabContents.map { widgetManager.text().apply { description = it } }
val tab = widgetManager.tab().apply {
    this.children = _children
    titles = _children.indices.map { it.toString() }
}
tab
// Out:
// TabModel(id=e1b404d8-b32a-43ab-a9fe-6d64de7fa080)

// %%
val tabNest = widgetManager.tab().apply {
    children = listOf(accordion, accordion)
    titles = listOf("An accordion", "Copy of the accordion")
}
tabNest
// Out:
// TabModel(id=756e728e-6e2e-4a6f-a0a2-669368c3941b)
