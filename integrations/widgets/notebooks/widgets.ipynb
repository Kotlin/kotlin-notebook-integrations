// %%
USE {
    repositories { mavenLocal() }
    dependencies {
        implementation("org.jetbrains.kotlinx:kotlin-jupyter-widgets-jupyter:0.3.0-1-SNAPSHOT")
    }
}
// TODO should use %use widgets

// %% [markdown]
// ### Int slider

// %%
intSliderWidget().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntSliderModel(id=d254fe94-d0b6-4775-9a02-75da4059c93f)

// %% [markdown]
// ### Float sliders

// %%
floatSliderWidget().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=fcae1c78-abbd-44db-a856-f1a6947e7d0c)

// %%
widgetManager.floatSlider().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Vertical
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=c61bdc06-767b-4cb1-b433-27890d984110)

// %%
widgetManager.floatLogSlider().apply {
    value = 10.0
    base = 10.0
    min = -10.0
    max = 10.0
    step = 0.2
    description = "Log Slider"
}
// Out:
// FloatLogSliderModel(id=20e9da25-63cd-4c64-8b21-f8f790239739)

// %% [markdown]
// ### Range sliders and progress

// %%
widgetManager.intRangeSlider().apply {
    value = 5..7
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntRangeSliderModel(id=561fd7cb-be67-48ce-a1d8-07533e73f9b5)

// %%
widgetManager.floatRangeSlider().apply {
    value = 5.0..7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatRangeSliderModel(id=2ad16b43-e775-4945-b206-eb4d2a10eb03)

// %%
widgetManager.intProgress().apply {
    value = 7
    min = 0
    max = 10
    description = "Loading:"
    barStyle = BarStyle.Default
    style = progressStyleWidget().apply { barColor = "maroon" }
    orientation = Orientation.Horizontal
}
// Out:
// IntProgressModel(id=b614a51e-53de-44ee-b828-0a3c0ed9e1e3)

// %%
widgetManager.floatProgress().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    description = "Loading:"
    barStyle = BarStyle.Info
    style = progressStyleWidget().apply { barColor = "#ffff00" }
    orientation = Orientation.Horizontal
}
// Out:
// FloatProgressModel(id=6dc10d04-5a62-410b-bd4c-d866eadc66cf)

// %% [markdown]
// ### Numeric text widgets

// %%
widgetManager.boundedIntText().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedIntTextModel(id=573701f6-2c95-4b14-a472-870675b9dd78)

// %%
widgetManager.boundedFloatText().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedFloatTextModel(id=b3cf3bd4-b9d7-4ecb-8294-91cc4951106d)

// %%
widgetManager.intText().apply {
    value = 7
    description = "Any:"
    disabled = false
}
// Out:
// IntTextModel(id=da08dfbc-184f-4e73-ac56-67f34a3623f8)

// %%
widgetManager.floatText().apply {
    value = 7.5
    description = "Any:"
    disabled = false
}
// Out:
// FloatTextModel(id=fda48ba1-3859-4210-8c64-d774dc41c046)

// %% [markdown]
// ### Toggles and indicators

// %%
widgetManager.toggleButton().apply {
    value = false
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Description"
    icon = "check"
}
// Out:
// ToggleButtonModel(id=3986be4b-3c6d-4a4e-91a6-665ac77f4fc7)

// %%
widgetManager.checkbox().apply {
    value = false
    description = "Check me"
    disabled = false
    indent = false
}
// Out:
// CheckboxModel(id=e6338730-3325-471e-9463-73c5732af92f)

// %%
widgetManager.valid().apply {
    value = false
    description = "Valid!"
}
// Out:
// ValidModel(id=8e4370fc-141b-42d9-ade4-19c0d80dd425)

// %% [markdown]
// ### Dropdowns and radios

// %%
widgetManager.dropdown().apply {
    simpleOptions = listOf("1", "2", "3")
    label = "2"
    description = "Number:"
    disabled = false
}
// Out:
// DropdownModel(id=5cfcf3c7-4d84-45ea-804b-b6dceffa7a76)

// %%
widgetManager.dropdown().apply {
    options = listOf(
        "One" to 1,
        "Two" to 2,
        "Three" to 3
    )
    value = 2
    description = "Number:"
}
// Out:
// DropdownModel(id=ddc541a9-4ebb-46fe-965e-b23ddce9ecaf)

// %%
widgetManager.radioButtons().apply {
    options = listOf("pepperoni", "pineapple", "anchovies").mapIndexed { index, string -> string to index }
    value = 1 // defaults to "pineapple"
    // layout = layoutWidget().apply { width = "max-content" } // If the items' names are long
    description = "Pizza topping:"
    disabled = false
}
// Out:
// RadioButtonsModel(id=50d83162-8d95-4606-9870-65ae5da4cbdd)

// %%
widgetManager.box().apply {
    children = listOf(
        labelWidget().apply { value = "Pizza topping with a very long label:" },
        radioButtonsWidget().apply {
            simpleOptions = listOf(
                "pepperoni",
                "pineapple",
                "anchovies",
                "and the long name that will fit fine and the long name that will fit fine and the long name that will fit fine "
            )
            layout = layoutWidget().apply { width = "max-content" }
        },
    )
}
// Out:
// BoxModel(id=819681f4-7186-4da7-966a-39bac713b4f3)

// %% [markdown]
// ### Selection widgets

// %%
widgetManager.select().apply {
    simpleOptions = listOf("Linux", "Windows", "OSX")
    value = "OSX"
    // rows = 10
    description = "OS:"
    disabled = false
}
// Out:
// SelectModel(id=765c41ab-e016-414b-87d4-12a0ea1c1051)

// %%
widgetManager.selectionSlider().apply {
    // TODO: options =
    optionsLabels = listOf("scrambled", "sunny side up", "poached", "over easy")
    index = 1
    description = "I like my eggs ..."
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
}
// Out:
// SelectionSliderModel(id=b44453d1-b603-4dc5-89ab-cdfe2157d80c)

// %%
%use datetime

// %%
val dates = (1..12).map { LocalDate(2015, it, 1) }
val options = dates.map { it.month.name.lowercase().replaceFirstChar(Char::titlecase) to it }
widgetManager.selectionRangeSlider().apply {
    // TODO this.options = options // currently impossible to have a different value/label
    optionsLabels = options.map { it.first }
    index = 0..11
    description = "Months (2015)"
    disabled = false
}
// Out:
// SelectionRangeSliderModel(id=683c0c65-f2f1-4ed1-83c7-8f25daa4167b)

// %%
widgetManager.toggleButtons().apply {
    simpleOptions = listOf("Slow", "Regular", "Fast")
    description = "Speed:"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltips = listOf("Description of slow", "Description of regular", "Description of fast")
    icons = List(3) { "check" }
}
// Out:
// ToggleButtonsModel(id=a20e9536-1e96-41ff-b6be-9c52a4f88497)

// %%
widgetManager.selectMultiple().apply {
    // TODO options = listOf("Apples", "Oranges", "Pears")
    optionsLabels = listOf("Apples", "Oranges", "Pears")
    // TODO value = listOf("Oranges")
    index = listOf(1)
    // rows = 10
    description = "Fruits"
    disabled = false
}
// Out:
// SelectMultipleModel(id=36d41c1a-632a-4dc0-a387-5a767bf4637c)

// %% [markdown]
// ### Text inputs

// %%
widgetManager.text().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextModel(id=f5f8c9d9-a4ce-4005-9966-4057a8604f8b)

// %%
widgetManager.textarea().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextareaModel(id=6e2d7b7d-00a5-477f-aef8-b4936108a6bc)

// %%
widgetManager.combobox().apply {
    // value = "John"
    options = listOf("Paul", "John", "George", "Ringo")
    placeholder = "Choose Someone"
    description = "Combobox:"
    ensureOption = true
    disabled = false
}
// Out:
// ComboboxModel(id=fe0a88af-1ab1-4312-bfd1-e23b24983f25)

// %%
widgetManager.password().apply {
    value = "password"
    placeholder = "Enter password"
    description = "Password:"
    disabled = false
}
// Out:
// PasswordModel(id=debf2768-ca69-4e7d-9f02-1a5251e1a726)

// %% [markdown]
// ### Layout helpers and HTML

// %%
widgetManager.hbox().apply {
    children = listOf(
        labelWidget().apply { value = "The label" },
        floatSliderWidget()
    )
}
// Out:
// HBoxModel(id=51958f98-829a-48c1-803a-8df8d38cb306)

// %%
widgetManager.html().apply {
    value = "Hello <b>World</b>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLModel(id=df2082aa-815f-4a93-b025-bc19458db3be)

// %%
widgetManager.htmlMath().apply {
    value = "Some<i>HTML</i>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLMathModel(id=a07b3a1f-4e95-44b4-bc02-c44cc2358e54)

// %%
import java.io.File

val image = File("WidgetArch.png").readBytes()
widgetManager.image().apply {
    value = image
    format = "png"
    width = "300" // TODO should probably be Int
    height = "400"
}
// Out:
// ImageModel(id=1b6c3fb4-5e55-4ed9-9f9f-cc76754db714)

// %% [markdown]
// ### Buttons and links

// %%
val button = widgetManager.button().apply {
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Click me"
    icon = "check" // FontAwesome names without the `fa-` prefix)
}
button
// Out:
// ButtonModel(id=84986e3a-afbf-4838-9d0f-0eb5c3939a4d)

// %%
val play = widgetManager.play().apply {
    value = 50
    min = 0
    max = 100
    step = 1
    interval = 500
    description = "Press play"
    disabled = false
}
val slider = widgetManager.intSlider()

widgetManager.link().apply {
    source = play to "value"
    target = slider to "value"
}
widgetManager.hbox().apply { children = listOf(play, slider) }
// Out:
// HBoxModel(id=092ed944-4feb-41ed-bf0f-a8569bdbb250)

// %% [markdown]
// ### Pickers and upload

// %%
widgetManager.datePicker().apply {
    description = "Pick a Date"
    disabled = false
}
// Out:
// DatePickerModel(id=824c58e9-5550-4657-9ff4-b6feb7909d0f)

// %%
widgetManager.colorPicker().apply {
    concise = false
    description = "Pick a color"
    value = "blue"
    disabled = false
}
// Out:
// ColorPickerModel(id=0bdf4dcc-5814-416e-a060-9b00fdab3d0a)

// %%
widgetManager.fileUpload().apply {
    accept = "" // Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple = false // true to accept multiple files upload else false
}
// Out:
// FileUploadModel(id=45042cb7-62cb-42a5-88ec-2c377bfd9302)

// %%
widgetManager.controller().apply { index = 0 }
// Out:
// ControllerModel(id=60770b82-afa3-4dd1-b393-9f1ed060b417)

// %% [markdown]
// ### Containers

// %%
val itemsBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.box().apply {
    children = itemsBox
}
// Out:
// BoxModel(id=a8835ec9-cccb-4db3-ba50-fae861c0f669)

// %%
val itemsHBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.hbox().apply {
    children = itemsHBox
}
// Out:
// HBoxModel(id=a4b8b15b-3b94-45cb-8b8c-82b601285226)

// %%
val items = List(4) { widgetManager.label().apply { value = it.toString()} }
val leftBox = widgetManager.vbox().apply { children = listOf(items[0], items[1]) }
val rightBox = widgetManager.vbox().apply { children = listOf(items[2], items[3]) }
widgetManager.hbox().apply { children = listOf(leftBox, rightBox) }
// Out:
// HBoxModel(id=f9be7860-1490-4dd2-bc50-0cda57ba061e)

// %%
val gridItems = List(8) { widgetManager.label().apply { value = it.toString() } }
widgetManager.gridBox().apply {
    children = gridItems
    layout = layoutWidget().apply { gridTemplateColumns = "repeat(3, 100px)" }
}
// Out:
// GridBoxModel(id=3969783a-d21f-446e-827d-23ce03b743d1)

// %%
val accordion = widgetManager.accordion().apply {
    children = listOf(widgetManager.intSlider(), widgetManager.text())
    titles = listOf("Slider", "Text")
}
accordion
// Out:
// AccordionModel(id=2f954e45-f098-4f5e-8574-589270efca82)

// %%
val tabContents = listOf("P0", "P1", "P2", "P3", "P4")
val _children = tabContents.map { widgetManager.text().apply { description = it } }
val tab = widgetManager.tab().apply {
    this.children = _children
    titles = _children.indices.map { it.toString() }
}
tab
// Out:
// TabModel(id=d1b68e05-adcc-4286-a396-400e1e8c27c0)

// %%
val tabNest = widgetManager.tab().apply {
    children = listOf(accordion, accordion)
    titles = listOf("An accordion", "Copy of the accordion")
}
tabNest
// Out:
// TabModel(id=d6aab1c4-d46c-41b5-8887-c3030afbe47e)
