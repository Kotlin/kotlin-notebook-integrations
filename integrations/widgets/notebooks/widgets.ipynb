// %%
USE {
    repositories { mavenLocal() }
    dependencies {
        implementation("org.jetbrains.kotlinx:kotlin-jupyter-widgets-jupyter:0.3.0-1-SNAPSHOT")
    }
}
// TODO should use %use widgets

// %% [markdown]
// ### Int slider

// %%
intSliderWidget().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntSliderModel(id=63364feb-d55c-4b02-b67b-5679865fe61d)

// %% [markdown]
// ### Float sliders

// %%
floatSliderWidget().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=d9408967-9b80-4185-9fb8-13e9d7aba415)

// %%
widgetManager.floatSlider().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Vertical
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatSliderModel(id=1c4d4a6f-cec0-4d75-ba5a-4a943715156d)

// %%
widgetManager.floatLogSlider().apply {
    value = 10.0
    base = 10.0
    min = -10.0
    max = 10.0
    step = 0.2
    description = "Log Slider"
}
// Out:
// FloatLogSliderModel(id=9d163006-c2d6-45ca-9b34-4b112adbb16b)

// %% [markdown]
// ### Range sliders and progress

// %%
widgetManager.intRangeSlider().apply {
    value = listOf(5, 7) // TODO should better be an `IntRange`
    min = 0
    max = 10
    step = 1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = "d"
}
// Out:
// IntRangeSliderModel(id=6c9fab43-e8c1-4179-a773-dc357367c0f2)

// %%
widgetManager.floatRangeSlider().apply {
    value = listOf(5.0, 7.5) // TODO should better be a `DoubleRange`
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Test:"
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
    readoutFormat = ".1f"
}
// Out:
// FloatRangeSliderModel(id=8c0fa3cc-d711-4b4a-a305-aad47d12847e)

// %%
widgetManager.intProgress().apply {
    value = 7
    min = 0
    max = 10
    description = "Loading:"
    barStyle = BarStyle.Default
    style = progressStyleWidget().apply { barColor = "maroon" }
    orientation = Orientation.Horizontal
}
// Out:
// IntProgressModel(id=0d9563e3-6cad-4aec-a3f7-bcce137dfad8)

// %%
widgetManager.floatProgress().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    description = "Loading:"
    barStyle = BarStyle.Info
    style = progressStyleWidget().apply { barColor = "#ffff00" }
    orientation = Orientation.Horizontal
}
// Out:
// FloatProgressModel(id=d3b6588c-67e0-458d-a2cf-44085cf05c15)

// %% [markdown]
// ### Numeric text widgets

// %%
widgetManager.boundedIntText().apply {
    value = 7
    min = 0
    max = 10
    step = 1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedIntTextModel(id=3939fbe3-f0a6-4f39-9381-b0501f5a3b2b)

// %%
widgetManager.boundedFloatText().apply {
    value = 7.5
    min = 0.0
    max = 10.0
    step = 0.1
    description = "Text:"
    disabled = false
}
// Out:
// BoundedFloatTextModel(id=26bd3e33-2279-4dad-a03b-62b6ca8d0ba5)

// %%
widgetManager.intText().apply {
    value = 7
    description = "Any:"
    disabled = false
}
// Out:
// IntTextModel(id=98c35d1e-f556-4434-9120-80ab6c2862bf)

// %%
widgetManager.floatText().apply {
    value = 7.5
    description = "Any:"
    disabled = false
}
// Out:
// FloatTextModel(id=00ab4133-a1bc-4f20-92ac-d94431e00752)

// %% [markdown]
// ### Toggles and indicators

// %%
widgetManager.toggleButton().apply {
    value = false
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Description"
    icon = "check"
}
// Out:
// ToggleButtonModel(id=ebc56fbb-45f3-4a36-953a-fdf667cf6d8d)

// %%
widgetManager.checkbox().apply {
    value = false
    description = "Check me"
    disabled = false
    indent = false
}
// Out:
// CheckboxModel(id=d4393772-4aea-431a-9efe-7570c443fa30)

// %%
widgetManager.valid().apply {
    value = false
    description = "Valid!"
}
// Out:
// ValidModel(id=0569bd5b-a15e-4b6d-a9ef-4a24f793ad03)

// %% [markdown]
// ### Dropdowns and radios

// %%
widgetManager.dropdown().apply {
    simpleOptions = listOf("1", "2", "3")
    label = "2"
    description = "Number:"
    disabled = false
}
// Out:
// DropdownModel(id=3a851382-93ce-4cc0-b54e-817f31b31419)

// %%
widgetManager.dropdown().apply {
    options = listOf(
        "One" to 1,
        "Two" to 2,
        "Three" to 3
    )
    value = 2
    description = "Number:"
}
// Out:
// DropdownModel(id=4ba5c3ff-b10c-4edd-b98e-dc4c8fb3ccbe)

// %%
widgetManager.radioButtons().apply {
    options = listOf("pepperoni", "pineapple", "anchovies").mapIndexed { index, string -> string to index }
    value = 1 // defaults to "pineapple"
    // layout = layoutWidget().apply { width = "max-content" } // If the items' names are long
    description = "Pizza topping:"
    disabled = false
}
// Out:
// RadioButtonsModel(id=34be4626-033b-4407-97b2-59fa79c67bce)

// %%
widgetManager.box().apply {
    children = listOf(
        labelWidget().apply { value = "Pizza topping with a very long label:" },
        radioButtonsWidget().apply {
            simpleOptions = listOf(
                "pepperoni",
                "pineapple",
                "anchovies",
                "and the long name that will fit fine and the long name that will fit fine and the long name that will fit fine "
            )
            layout = layoutWidget().apply { width = "max-content" }
        },
    )
}
// Out:
// BoxModel(id=857e70bb-5009-47a5-b27c-ac389759213c)

// %% [markdown]
// ### Selection widgets

// %%
widgetManager.select().apply {
    simpleOptions = listOf("Linux", "Windows", "OSX")
    value = "OSX"
    // rows = 10
    description = "OS:"
    disabled = false
}
// Out:
// SelectModel(id=bf0643fc-75eb-488f-b866-3afbaabf0ca4)

// %%
widgetManager.selectionSlider().apply {
    // TODO: options =
    optionsLabels = listOf("scrambled", "sunny side up", "poached", "over easy")
    index = 1
    description = "I like my eggs ..."
    disabled = false
    continuousUpdate = false
    orientation = Orientation.Horizontal
    readout = true
}
// Out:
// SelectionSliderModel(id=43ef405d-ea0f-4215-a030-4a1f7f2416f3)

// %%
%use datetime

// %%
val dates = (1..12).map { LocalDate(2015, it, 1) }
val options = dates.map { it.month.name.lowercase().replaceFirstChar(Char::titlecase) to it }
widgetManager.selectionRangeSlider().apply {
    // TODO this.options = options // currently impossible to have a different value/label
    optionsLabels = options.map { it.first }
    index = listOf(0, 11) // TODO should be IntRange
    description = "Months (2015)"
    disabled = false
}
// Out:
// SelectionRangeSliderModel(id=5c61686c-4344-44c6-849d-43eca0ee5e50)

// %%
widgetManager.toggleButtons().apply {
    simpleOptions = listOf("Slow", "Regular", "Fast")
    description = "Speed:"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltips = listOf("Description of slow", "Description of regular", "Description of fast")
    icons = List(3) { "check" }
}
// Out:
// ToggleButtonsModel(id=f6076582-d97f-46cc-8445-1408f40e3e3f)

// %%
widgetManager.selectMultiple().apply {
    // TODO options = listOf("Apples", "Oranges", "Pears")
    optionsLabels = listOf("Apples", "Oranges", "Pears")
    // TODO value = listOf("Oranges")
    index = listOf(1)
    // rows = 10
    description = "Fruits"
    disabled = false
}
// Out:
// SelectMultipleModel(id=82672ea1-a52b-4dde-b3a4-13df186049d7)

// %% [markdown]
// ### Text inputs

// %%
widgetManager.text().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextModel(id=ec0d0683-4ed7-454e-a9d0-4c92abcc5c13)

// %%
widgetManager.textarea().apply {
    value = "Hello World"
    placeholder = "Type something"
    description = "String:"
    disabled = false
}
// Out:
// TextareaModel(id=9e7c6660-5d06-4dd5-bce4-4dbbbe4b1c5e)

// %%
widgetManager.combobox().apply {
    // value = "John"
    options = listOf("Paul", "John", "George", "Ringo")
    placeholder = "Choose Someone"
    description = "Combobox:"
    ensureOption = true
    disabled = false
}
// Out:
// ComboboxModel(id=5535ca59-6135-4498-b1ef-f3eeafd97243)

// %%
widgetManager.password().apply {
    value = "password"
    placeholder = "Enter password"
    description = "Password:"
    disabled = false
}
// Out:
// PasswordModel(id=ccb9b95b-0291-4d29-a0c2-573e232e0417)

// %% [markdown]
// ### Layout helpers and HTML

// %%
widgetManager.hbox().apply {
    children = listOf(
        labelWidget().apply { value = "The label" },
        floatSliderWidget()
    )
}
// Out:
// HBoxModel(id=353e87c1-92b7-4390-ad27-c2bd8c812101)

// %%
widgetManager.html().apply {
    value = "Hello <b>World</b>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLModel(id=6086a1eb-a076-4021-8950-b6cb5422da67)

// %%
widgetManager.htmlMath().apply {
    value = "Some<i>HTML</i>"
    placeholder = "Some HTML"
    description = "Some HTML"
}
// Out:
// HTMLMathModel(id=d588101a-86ca-4ee3-9839-a98b645dd9e1)

// %%
import java.io.File

val image = File("WidgetArch.png").readBytes()
widgetManager.image().apply {
    value = image
    format = "png"
    width = "300" // TODO should probably be Int
    height = "400"
}
// Out:
// ImageModel(id=95864030-57c5-424e-881f-e031adfb6409)

// %% [markdown]
// ### Buttons and links

// %%
val button = widgetManager.button().apply {
    description = "Click me"
    disabled = false
    buttonStyle = ButtonStyle.Default
    tooltip = "Click me"
    icon = "check" // FontAwesome names without the `fa-` prefix)
}
button
// Out:
// ButtonModel(id=3395a47f-ab90-4b64-b2d4-215a9a2a43d8)

// %%
val play = widgetManager.play().apply {
    value = 50
    min = 0
    max = 100
    step = 1
    interval = 500
    description = "Press play"
    disabled = false
}
val slider = widgetManager.intSlider()
// TODO jslink(play to "value", slider to "value")
// TODO missing TupleType or PairType
//   widgetManager.link().apply {
//       source = listOf(play, "value") // TODO should definitely be a Pair<Widget, String>
//       target = listOf(slider, "value")
//   }
widgetManager.hbox().apply { children = listOf(play, slider) }
// Out:
// HBoxModel(id=f194e68a-810c-4477-9c2a-43c085340f3c)

// %% [markdown]
// ### Pickers and upload

// %%
widgetManager.datePicker().apply {
    description = "Pick a Date"
    disabled = false
}
// Out:
// DatePickerModel(id=350a29e8-2010-4441-8c6d-5343a3f6c1d7)

// %%
widgetManager.colorPicker().apply {
    concise = false
    description = "Pick a color"
    value = "blue"
    disabled = false
}
// Out:
// ColorPickerModel(id=bb8a3480-725d-4e6e-8b42-579611cf8e2f)

// %%
widgetManager.fileUpload().apply {
    accept = "" // Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple = false // true to accept multiple files upload else false
}
// Out:
// FileUploadModel(id=67e5ffd6-ba0d-44c2-bebb-6c08a02fad8c)

// %%
widgetManager.controller().apply { index = 0 }
// Out:
// ControllerModel(id=a3ffb9dd-005f-49e4-967d-81297ff365fd)

// %% [markdown]
// ### Containers

// %%
val itemsBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.box().apply {
    children = itemsBox
}
// Out:
// BoxModel(id=ae87db91-f8cf-4a6b-a150-3f7e411ddde7)

// %%
val itemsHBox = List(4) { widgetManager.label().apply { value = it.toString() } }
widgetManager.hbox().apply {
    children = itemsHBox
}
// Out:
// HBoxModel(id=49a647b3-5073-4519-a3c4-3b32eeaf0dd8)

// %%
val items = List(4) { widgetManager.label().apply { value = it.toString()} }
val leftBox = widgetManager.vbox().apply { children = listOf(items[0], items[1]) }
val rightBox = widgetManager.vbox().apply { children = listOf(items[2], items[3]) }
widgetManager.hbox().apply { children = listOf(leftBox, rightBox) }
// Out:
// HBoxModel(id=9a67deb2-0a8f-442c-b9c1-8571143af7dc)

// %%
val gridItems = List(8) { widgetManager.label().apply { value = it.toString() } }
widgetManager.gridBox().apply {
    children = gridItems
    layout = layoutWidget().apply { gridTemplateColumns = "repeat(3, 100px)" }
}
// Out:
// GridBoxModel(id=f2dae378-4b67-4a4a-b676-115f2a5cbde8)

// %%
val accordion = widgetManager.accordion().apply {
    children = listOf(widgetManager.intSlider(), widgetManager.text())
    titles = listOf("Slider", "Text")
}
accordion
// Out:
// AccordionModel(id=1aac2129-bf8c-4e0d-a2be-fbc5ab579c99)

// %%
val tabContents = listOf("P0", "P1", "P2", "P3", "P4")
val _children = tabContents.map { widgetManager.text().apply { description = it } }
val tab = widgetManager.tab().apply {
    this.children = _children
    titles = _children.indices.map { it.toString() }
}
tab
// Out:
// TabModel(id=a09ea2df-8c77-453e-aa34-bbc0a4bf6bbb)

// %%
val tabNest = widgetManager.tab().apply {
    children = listOf(accordion, accordion)
    titles = listOf("An accordion", "Copy of the accordion")
}
tabNest
// Out:
// TabModel(id=46c726fb-d035-4cb1-8dfb-9bbff7bf3276)
